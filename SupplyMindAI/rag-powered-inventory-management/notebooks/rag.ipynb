# %%
import pandas as pd

# %%
df = pd.read_csv('../data/raw/inventory_enriched_rag_ready.csv')
print("Data Loaded Successfully !")
# Out:
# Data Loaded Successfully !

# %%
df.head()
# Out:
#          date product_id  stock      product_name category      type  \
# 0  2020-01-01    FAN_STD    204               Fan  Cooling  Standard
# 1  2020-01-01    EX_FLAT    330      Exhaust Flat  Cooling   Exhaust
# 2  2020-01-01    EX_POLY    570   Exhaust Polygon  Cooling   Exhaust
# 3  2020-01-01    EX_CIRC    264  Exhaust Circular  Cooling   Exhaust
# 4  2020-01-01       AF_5    600      Air Fryer 5L  Kitchen  AirFryer
#
#    is_active  avg_daily_demand  coverage_days stock_status  \
# 0       True         85.319102           2.39     Critical
# 1       True        125.043788           2.64     Critical
# 2      False          0.000000            NaN      Healthy
# 3       True         83.181171           3.17     Critical
# 4       True         39.338807          15.25      Healthy
#
#                                coverage_days_display  \
# 0                                          2.39 days
# 1                                          2.64 days
# ...

# %%
print(df.shape)
print(df.isnull().sum())
print(df.duplicated().sum())
print(df.columns)
# Out:
# (23751, 13)
# date                        0
# product_id                  0
# stock                       0
# product_name                0
# category                    0
# type                        0
# is_active                   0
# avg_daily_demand            0
# coverage_days            3654
# stock_status                0
# coverage_days_display       0
# coverage_days_reason        0
# inventory_fact_text         0
# dtype: int64
# 0
# Index(['date', 'product_id', 'stock', 'product_name', 'category', 'type',
#        'is_active', 'avg_daily_demand', 'coverage_days', 'stock_status',
#        'coverage_days_display', 'coverage_days_reason', 'inventory_fact_text'],
#       dtype='object')
